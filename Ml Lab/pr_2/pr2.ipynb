# %%
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   27                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df[['age']], df.bought_insurance, marker='+', color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, test_size=0.1)

# %%
x_test
# Out:
#     age
# 12   27
# 20   21
# 10   18

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 0, 0])

# %%
model.score(x_test, y_test)
# Out:
# 1.0

# %%
model.predict_proba(x_test)
# Out:
# array([[0.80161756, 0.19838244],
#        [0.8958041 , 0.1041959 ],
#        [0.92614697, 0.07385303]])

# %%
import numpy as np

# %%
plt.scatter(df.age, df.bought_insurance, marker='+', color='red')

age_range = np.linspace(df.age.min(), df.age.max(), 300)
y_prob = model.predict_proba(age_range.reshape(-1, 1))[:, 1]

plt.plot(age_range, y_prob, color='blue')

plt.xlabel('Age')
plt.ylabel('Probability')
plt.show()
# Out:
# c:\Users\Dixita\Downloads\MTech AI Sem-1\Ml Lab\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
